# %%
# checking the Nvidia configuration
# !nvidia-smi
# Out:
# Sat Mar 23 06:57:10 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.03             Driver Version: 535.129.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8               9W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# # connecting to the drive
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
HOME = os.getcwd() + '/yolo'
os.makedirs(HOME,exist_ok=True)
HOME
# Out:
# '/kaggle/working/yolo/yolo/datasets/yolo/datasets/yolo'

# %%
# !pip install ultralytics==8.0.196

# %%
from IPython import display
display.clear_output

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5520.0/8062.4 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import Image,display

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# Out:
# /kaggle/working/yolo/yolo/datasets/yolo/datasets/yolo/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Your roboflow_api_key")
project = rf.workspace("cs-6fbpy").project("check-xjfsb")
version = project.version(11)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to check-11 in yolov8:: 100%|██████████| 4422/4422 [00:00<00:00, 9439.17it/s]

# %%
# %cd {HOME}
# Out:
# /kaggle/working/yolo/yolo/datasets/yolo/datasets/yolo

# %%
# !yolo task=detect mode=train model= yolov8l.pt data={dataset.location}/data.yaml epochs=50 patience=30 imgsz=800 plots=True project={HOME}/runs/detect device=[0,1]
# Out:
# ...
# 100%|███████████████████████████████████████| 83.7M/83.7M [00:00<00:00, 301MB/s]
# New https://pypi.org/project/ultralytics/8.1.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
#                                                        CUDA:1 (Tesla T4, 15102MiB)
# ...

# %%
import shutil
shutil.make_archive('/kaggle/working/outpur_vehicle','zip',f'{HOME}/runs/detect/train')
# Out:
# '/kaggle/working/test-1.zip'
